# %% [markdown]
# # Run DCEO Agent Training with Output Streaming
#
# This notebook runs the DCEO training with real-time output.

# %%
# Check CUDA
import torch
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA device: {torch.cuda.get_device_name(0)}")
# Out:
# CUDA available: True
# CUDA device: NVIDIA GeForce RTX 3070 Ti

# %%
# Run with real-time output streaming
import subprocess
import sys

# This will stream output in real-time
process = subprocess.Popen(
    "python compare_key_maze_agents.py --episodes 20 --eval_interval 10 --maze_size 10 --num_keys 1 --max_steps 300 --skip standard count rnd --fixed_maze",
    shell=True,
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    universal_newlines=True,
    bufsize=1
)

# Stream the output as it comes
for line in process.stdout:
    print(line, end='')
    sys.stdout.flush()  # Force output to be displayed immediately

# Wait for process to complete
process.wait()
# Out:
# Starting agent comparison experiment with Key-Door Maze
# Training each agent for 20 episodes
# Evaluating every 10 episodes with 10 eval episodes
# Maze size: 10, Keys: 1, Max steps: 300
# Using device: cuda
# Using fixed maze layout with seed 42
# Environment: Key-Door Maze
# Observation shape: (16, 84, 84), PyTorch shape: (16, 84, 84)
# Action size: 4
#
# ===== Training Rainbow DCEO Agent =====
# RepNet initialized with: input=(16, 84, 84), conv_out=3136, rep_dim=8
# Moved all networks to cuda
# Starting Episode 1 with epsilon 1.0000
# Figure(800x800)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
#   Step 28: Collected key 1
# Figure(640x480)
#   Step 29: Switched to option 0
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
#   Step 50: Reward so far: 1.56, Keys: 1, Doors: 0
#   Current epsilon: 0.8262
#   Current option: 0
# Figure(640x480)
# Figure(640x480)
#   Step 58: Switched to option 6
# Figure(640x480)
# Figure(640x480)
# ...
