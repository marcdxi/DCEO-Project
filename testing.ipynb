# %%
# !set CUDA_VISIBLE_DEVICES=0 && python maze_experiment/train_maze_online_dceo_with_viz.py --maze_size 12 --iterations 25 --steps 200 --seed 1925 --fixed_layout
# Out:
# Using device: cuda
# Training fully online DCEO agent on Complex Maze
# Generated valid maze after 1 attempts
# Fully Online Rainbow DCEO Agent initialized on cuda
# Network architecture: Noisy=False, Dueling=True, Distributional=True
# DCEO parameters: Options=5, Rep Dim=64, Orthonormal=True
# Metrics will be saved to: maze_results\run_20250509_122829
# Device: cuda
#
# Iteration 1/25 - Training
#   Episode 1 completed after 200 steps
#   Reward: -1.20, Success: False
# Iteration 1 completed. Time elapsed: 0.1s, ETA: 1.3s
#
# Iteration 2/25 - Training
#   Episode 3 completed after 200 steps
#   Reward: -0.70, Success: False
# Iteration 2 completed. Time elapsed: 0.1s, ETA: 1.3s
#
# Iteration 3/25 - Training
#   Episode 5 completed after 200 steps
#   Reward: -0.80, Success: False
# Iteration 3 completed. Time elapsed: 0.2s, ETA: 1.2s
#
# Iteration 4/25 - Training
#   Episode 7 completed after 200 steps
#   Reward: -1.15, Success: False
# ...
